# %% [markdown]
# # Лабораторная работа 6.
# # Сетевые алгоритмы. Динамические алгоритмы поиска путей.

# %% [markdown]
# ## Выполнил студент группы БВТ2004 Гончаренко Анастасия
# ***

# %% [markdown]
# ### Задание
#
# 1.  Реализовать алгоритм поиска кратчайшего расстояния между двумя вершинами ориентированного взвешенного графа в соответствии с вариантом.
#
# 2.  Предусмотреть задание графа в виде матрицы смежности/инцидентности, читаемой из файла, либо графически с помощью пользовательского интерфейса.
#
# 3.  Разработать графический интерфейс пользователя с визуализацией графа и отображением кратчайшего расстояния между задаваемыми пользователем вершинами.
#
# 4. По результатам работы проанализировать временную сложность работы заданного алгоритма в зависимости от числа узлов и ребер графа.
# Данные представить в виде таблицы.

# %% [markdown]
# ### Алгоритмы:
#
# Алгоритм Флойда-Уоршелла| Алгоритм Дейкстры | Алгоритм Беллмана-Форда | Алгоритм Джонсона| Алгоритм Левита | Алгоритм Йена

# %% [markdown]
# ### Выполнение:

# %%
# !pip install pyvis
import pandas as pd
import networkx as nx

import math
import copy
import random
import time
from pyvis.network import Network
# Out:
# Requirement already satisfied: pyvis in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (0.2.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from pyvis) (2.1.0)
# Requirement already satisfied: jinja2>=2.9.6 in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from pyvis) (3.0.3)
# Requirement already satisfied: networkx>=1.11 in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from pyvis) (2.8)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from pyvis) (8.0.1)
# Requirement already satisfied: pickleshare in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: traitlets>=5 in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: matplotlib-inline in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.3.0->pyvis) (0.1.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.3.0->pyvis) (3.0.26)
# Requirement already satisfied: colorama in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.3.0->pyvis) (0.4.4)
# Requirement already satisfied: setuptools>=18.5 in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.3.0->pyvis) (58.1.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.3.0->pyvis) (0.18.1)
# Requirement already satisfied: stack-data in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.3.0->pyvis) (0.1.4)
# Requirement already satisfied: pygments in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.3.0->pyvis) (2.11.2)
# Requirement already satisfied: black in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.3.0->pyvis) (22.1.0)
# Requirement already satisfied: backcall in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: decorator in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from jinja2>=2.9.6->pyvis) (2.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis) (0.2.5)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from black->ipython>=5.3.0->pyvis) (2.0.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from black->ipython>=5.3.0->pyvis) (8.0.3)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from black->ipython>=5.3.0->pyvis) (0.4.3)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from black->ipython>=5.3.0->pyvis) (0.9.0)
# Requirement already satisfied: platformdirs>=2 in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from black->ipython>=5.3.0->pyvis) (2.4.1)
# Requirement already satisfied: asttokens in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.2.2)
# Requirement already satisfied: executing in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.8.2)
# Requirement already satisfied: six in c:\users\анастасия\appdata\local\programs\python\python310\lib\site-packages (from asttokens->stack-data->ipython>=5.3.0->pyvis) (1.16.0)

# %%
def generate_matrix():
    size = random.randint(30, 100)
    matrix = [[math.inf for i in range(size)] for j in range(size)]
    for i in range(size):
        for j in range(size):
            if random.randint(0, 3) == 3 and i != j:
                rand_count = random.randint(1, 20)
                matrix[i][j] = rand_count
    return matrix

# %%
options = """var options = {
  "edges": {
    "arrows": {
      "to": {
        "enabled": true
      }
    },
    "color": {
      "inherit": true
    },
    "smooth": false
  },
  "interaction": {
    "navigationButtons": true
  },
  "physics": {
    "minVelocity": 0.75
  }
}
"""

# %%
def create_graph(matrix : list) -> nx.DiGraph:
    graph = nx.DiGraph()
    for i in range(1, len(matrix)):
        graph.add_node(i)
    for i in range(len(matrix)):
        for j in range(len(matrix)):
            if matrix[i][j] != math.inf and i != j:
                graph.add_edge(i + 1, j + 1, weight=matrix[i][j], label=matrix[i][j])
    for edge in graph.edges():
        graph.edges[edge]['color'] = 'blue'
    return graph

# %%
#АЛГОРИТМ ФЛОЙДА-УОРШЕЛЛА

with open("mat2.txt", "r", encoding = "utf-8") as file:
    matrix = [[int(num) for num in line.split(" ")] for line in file]
    for i in range(len(matrix)):
        for j in range(len(matrix)):
            if matrix[i][j] == 0:
                matrix[i][j] = math.inf
                
graph = create_graph(matrix)

# %%
def get_path(H, v, u):
    v -= 1
    u -= 1
    result = []
    result.append(v)
    while v != u:
        v = H[v][u]
        result.append(v)
    __result = [el + 1 for el in result]
    return __result


def floyd(matrix):
    W = copy.deepcopy(matrix)
    N = len(W)
    H = [[0 for i in range(N)] for j in range(N)]
    for i in range(len(W)):
        for j in range(len(W)):
            if W[i][j] != math.inf:
                H[i][j] = j
    for i in range(len(W)):
        for j in range(len(W)):
            if i == j: continue
            if W[i][j] != math.inf:
                for k in range(len(W)):
                    if i == k or j == k: continue
                    if W[i][k] > W[i][j] + W[j][k]:
                        W[i][k] = W[i][j] + W[j][k]
                        H[i][k] = H[i][j]
    return (W, H)


result = floyd(matrix)
print(result)
path = get_path(result[1], 1, 3)

print(path)
#вносим графические изменения
graph1 = copy.deepcopy(graph)
for i in range(1, len(path)):
    graph1.nodes[path[i - 1]]['color'] = 'red'
    graph1.edges[path[i - 1], path[i]]['color'] = 'red'
graph1.nodes[path[-1]]['color'] = 'red'

#отображаем граф с решением
nt1 = Network(notebook=True)
nt1.set_options(options)
nt1.from_nx(graph1)
nt1.show("test1.html")
# Out:
# ([[inf, 10, 30, 50, 40], [inf, inf, inf, inf, inf], [20, inf, inf, 40, 10], [40, 40, 20, inf, 30], [10, 20, 10, 30, inf]], [[0, 1, 2, 3, 2], [0, 0, 0, 0, 0], [4, 0, 0, 4, 4], [2, 1, 2, 0, 2], [0, 0, 2, 3, 0]])
# [1, 3]
#         <iframe
#             width="500px"
#             height="500px"
#             src="test1.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
tests = []

for i in range(6):
    temp_matrix = generate_matrix()
    node_counts = len(temp_matrix)
    edge_counts = 0
    for i in range(len(temp_matrix)):
        for j in range(len(temp_matrix)):
            if temp_matrix[i][j] != math.inf:
                edge_counts += 1
    t1 = time.time()
    result = floyd(temp_matrix)
    t2 = time.time()
    delta = round((t2 - t1) * 1000)
    tests.append([node_counts, edge_counts, delta])

pd.DataFrame(tests, columns = ["Количество узлов", "Количество ребер", "Время в мс"])
# Out:
#    Количество узлов  Количество ребер  Время в мс
# 0                36               344          33
# 1                83              1683         381
# 2                85              1739         391
# 3                96              2357         593
# 4                40               406          40
# 5                83              1750         368

# %%
#АЛГОРИТМ ДЕЙКСТРЫ

with open("mat2.txt", "r", encoding = "utf-8") as file:
    matrix = [[int(num) for num in line.split(" ")] for line in file]
    for i in range(len(matrix)):
        for j in range(len(matrix)):
            if matrix[i][j] == 0:
                matrix[i][j] = math.inf
                
graph = create_graph(matrix)

# %%
def dijkstra(__matrix, v, u):
    matrix = copy.deepcopy(__matrix)
    v -= 1
    u -= 1
    N = len(matrix)
    D = [matrix[v][i] for i in range(N)]
    D[v] = 0
    P = [[v] for i in range(N)]
    checked_nodes = {v}
    for i in range(N):
        temp_min = math.inf
        node = None
        for j in range(N):
            if D[j] < temp_min and j not in checked_nodes:
                temp_min = D[j]
                node = j
        if node is not None:
            checked_nodes.add(node)
            for k in range(N):
                if D[k] > matrix[node][k] + D[node]:
                    D[k] = matrix[node][k] + D[node]
                    P[k] = copy.deepcopy(P[node])
                    P[k].append(node)
        else:
            break
                    
    for i in range(N):
        if D[i] != math.inf and P[i][0] != i:
            P[i].append(i)
    
    if D[u] == math.inf:
        path = []
    else:
        path = [el + 1 for el in P[u]]
    return (D, path, P)



result = dijkstra(matrix, 1, 3)
path = result[1]

graph1 = copy.deepcopy(graph)
if len(path) > 0:
    for i in range(1, len(path)):
        graph1.nodes[path[i - 1]]['color'] = 'red'
        graph1.edges[path[i - 1], path[i]]['color'] = 'red'
    graph1.nodes[path[-1]]['color'] = 'red'

nt1 = Network(notebook=True)
nt1.set_options(options)
nt1.from_nx(graph1)
nt1.show("test1.html")
# Out:
#         <iframe
#             width="500px"
#             height="500px"
#             src="test1.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
tests = []

for i in range(6):
    temp_matrix = generate_matrix()
    node_counts = len(temp_matrix)
    edge_counts = 0
    for i in range(len(temp_matrix)):
        for j in range(len(temp_matrix)):
            if temp_matrix[i][j] != math.inf:
                edge_counts += 1
    t1 = time.time()
    c1 = random.randint(1, len(temp_matrix) // 2)
    c2 = random.randint(1, len(temp_matrix))
    result = dijkstra(temp_matrix, c1, c2)
    t2 = time.time()
    delta = round((t2 - t1) * 1000)
    tests.append([node_counts, edge_counts, delta])

pd.DataFrame(tests, columns = ["Количество узлов", "Количество ребер", "Время в мс"])
# Out:
#    Количество узлов  Количество ребер  Время в мс
# 0                77              1451          14
# 1                68              1189          10
# 2                93              2176          19
# 3                95              2225          19
# 4                41               410           5
# 5                34               280           2

# %%
#Алгоритм Беллмана-Форда

with open("mat2.txt", "r", encoding = "utf-8") as file:
    matrix = [[int(num) for num in line.split(" ")] for line in file]
    for i in range(len(matrix)):
        for j in range(len(matrix)):
            if matrix[i][j] == 0:
                matrix[i][j] = math.inf
                
graph = create_graph(matrix)

# %%
def bell_ford(matrix, v, u):
    v -= 1
    u -= 1
    N = len(matrix)
    cycle = False
    A = [[math.inf for i in range(N)] for j in range(N)]
    P = [[v] for i in range(N)]
    A[0][v] = 0
    for k in range(1, N):
        A[k] = copy.deepcopy(A[k - 1])
        for i in range(N):
            for j in range(N):
                if matrix[i][j] == math.inf:
                    continue
                if A[k][j] > A[k - 1][i] + matrix[i][j]:
                    A[k][j] = A[k - 1][i] + matrix[i][j]
                    P[j] = copy.deepcopy(P[i])
                    P[j].append(j)
    if A[-1] != A[-2]:
        cycle = True
    if A[-1][u] == math.inf or len(P[u]) == 1:
        path = []
    else:
        path = [el + 1 for el in P[u]]
    return (A[-1], path, P, cycle)

result = bell_ford(matrix, 1, 3)
path = result[1]

#вносим графические изменения
graph1 = copy.deepcopy(graph)
if len(path) > 0:
    for i in range(1, len(path)):
        graph1.nodes[path[i - 1]]['color'] = 'red'
        graph1.edges[path[i - 1], path[i]]['color'] = 'red'
    graph1.nodes[path[-1]]['color'] = 'red'
    

#отображаем граф с решением
nt1 = Network(notebook=True)
nt1.set_options(options)
nt1.from_nx(graph1)
nt1.show("test1.html")
# Out:
#         <iframe
#             width="500px"
#             height="500px"
#             src="test1.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#тестовый блок для определения скорости работы алгоритма

tests = []

for i in range(6):
    temp_matrix = generate_matrix()
    node_counts = len(temp_matrix)
    edge_counts = 0
    for i in range(len(temp_matrix)):
        for j in range(i):
            if temp_matrix[j][i] != 0:
                edge_counts += 1
    t1 = time.time()
    c1 = random.randint(1, len(temp_matrix) // 2)
    c2 = random.randint(1, len(temp_matrix))
    result = bell_ford(temp_matrix, c1, c2)
    t2 = time.time()
    delta = round((t2 - t1) * 1000)
    tests.append([node_counts, edge_counts, delta])

pd.DataFrame(tests, columns = ["Количество узлов", "Количество ребер", "Время в мс"])
# Out:
#    Количество узлов  Количество ребер  Время в мс
# 0                41               820          47
# 1                39               741          42
# 2                35               595          41
# 3                81              3240         225
# 4                60              1770         123
# 5                78              3003         247

# %%
#Алгоритм Джонсона

#загрузка матрицы из файла
with open("mat2.txt", "r", encoding = "utf-8") as file:
    matrix = [[int(num) for num in line.split(" ")] for line in file]
    for i in range(len(matrix)):
        for j in range(len(matrix)):
            if matrix[i][j] == 0:
                matrix[i][j] = math.inf
                
#создаём граф
graph = create_graph(matrix)

# %%
#алгоритм
def johnson(__matrix, v, u):
    v -= 1
    u -= 1
    w = copy.deepcopy(__matrix)
    matrix = copy.deepcopy(__matrix)
    N = len(matrix)
    for i in range(N):
        w[i].append(math.inf)
    w.append([0 for i in range(N + 1)])
    temp_result = bell_ford(w, N + 1, 1)
    if temp_result[3] == True:
        return ([], [], [])
    for i in range(N):
        for j in range(N):
            if matrix[i][j] != math.inf and temp_result[0][i] != math.inf and temp_result[0][j] != math.inf:
                matrix[i][j] += temp_result[0][i] - temp_result[0][j]
    distArr = []
    pathArr = []
    for i in range(N):
        dijkstra_result = dijkstra(matrix, i + 1, i + 1)
        distArr.append(dijkstra_result[0])
        pathArr.append(dijkstra_result[2])
    for i in range(N):
        for j in range(N):
            if distArr[i][j] != math.inf and temp_result[0][i] != math.inf and temp_result[0][j] != math.inf:
                distArr[i][j] += temp_result[0][j] - temp_result[0][i]
    
    return (distArr, [el + 1 for el in pathArr[v][u]], pathArr)


result = johnson(matrix, 1, 3)
path = result[1]

#вносим графические изменения
graph1 = copy.deepcopy(graph)
if len(path) > 0:
    for i in range(1, len(path)):
        graph1.nodes[path[i - 1]]['color'] = 'red'
        graph1.edges[path[i - 1], path[i]]['color'] = 'red'
    graph1.nodes[path[-1]]['color'] = 'red'


#отображаем граф с решением
nt1 = Network(notebook=True)
nt1.set_options(options)
nt1.from_nx(graph1)
nt1.show("test1.html")
# Out:
#         <iframe
#             width="500px"
#             height="500px"
#             src="test1.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#тестовый блок для определения скорости работы алгоритма

tests = []

for i in range(6):
    temp_matrix = generate_matrix()
    node_counts = len(temp_matrix)
    edge_counts = 0
    for i in range(len(temp_matrix)):
        for j in range(i):
            if temp_matrix[j][i] != 0:
                edge_counts += 1
    t1 = time.time()
    c1 = random.randint(1, len(temp_matrix) // 2)
    c2 = random.randint(1, len(temp_matrix))
    result = johnson(temp_matrix, c1, c2)
    t2 = time.time()
    delta = round((t2 - t1) * 1000)
    tests.append([node_counts, edge_counts, delta])

pd.DataFrame(tests, columns = ["Количество узлов", "Количество ребер", "Время в мс"])
# Out:
#    Количество узлов  Количество ребер  Время в мс
# 0                37               666         173
# 1                62              1891         630
# 2                87              3741        1747
# 3                55              1485         501
# 4                98              4753        2471
# 5                55              1485         491

# %%
#Алгоритм Левита

#загрузка матрицы из файла
with open("mat2.txt", "r", encoding = "utf-8") as file:
    matrix = [[int(num) for num in line.split(" ")] for line in file]
    for i in range(len(matrix)):
        for j in range(len(matrix)):
            if matrix[i][j] == 0:
                matrix[i][j] = math.inf
#создаём граф
graph = create_graph(matrix)

# %%
#алгоритм
def levit(__matrix, v, u):
    v -= 1
    u -= 1
    matrix = copy.deepcopy(__matrix)
    N = len(matrix)
    paths = [[v] for i in range(N)]
    distance = [math.inf for i in range(N)]
    distance[v] = 0
    m0 = set()
    m1 = {"main_queue" : [v], "urgent_queue": []}
    m2 = set(range(N))
    m2.remove(v)
    while len(m1["main_queue"]) or len(m1["urgent_queue"]):
        if len(m1["urgent_queue"]):
            cur_node = m1["urgent_queue"].pop(0)
        else:
            cur_node = m1["main_queue"].pop(0)
        for temp_node in range(N):
            if distance[temp_node] == math.inf and matrix[cur_node][temp_node] == math.inf:
                continue
            if temp_node in m2:
                m2.remove(temp_node)
                calculated_distance = distance[cur_node] + matrix[cur_node][temp_node]
                if calculated_distance < distance[temp_node]:
                    distance[temp_node] = calculated_distance
                    paths[temp_node] = copy.deepcopy(paths[cur_node])
                    paths[temp_node].append(temp_node)
                m1["main_queue"].append(temp_node)
            elif temp_node in m1["main_queue"] or temp_node in m1["urgent_queue"]:
                calculated_distance = distance[cur_node] + matrix[cur_node][temp_node]
                if calculated_distance < distance[temp_node]:
                    distance[temp_node] = calculated_distance
                    paths[temp_node] = copy.deepcopy(paths[cur_node])
                    paths[temp_node].append(temp_node)
            elif temp_node in m0 and distance[temp_node] > distance[cur_node] + matrix[cur_node][temp_node]:
                m0.remove(temp_node)
                m1["urgent_queue"].append(temp_node)
                calculated_distance = distance[cur_node] + matrix[cur_node][temp_node]
                if calculated_distance < distance[temp_node]:
                    distance[temp_node] = calculated_distance
                    paths[temp_node] = copy.deepcopy(paths[cur_node])
                    paths[temp_node].append(temp_node)
        m0.add(cur_node)
    return distance, [el + 1 for el in paths[u]], paths

result = levit(matrix, 1, 3)
path = result[1]
#вносим графические изменения
graph1 = copy.deepcopy(graph)
if len(path) > 0:
    for i in range(1, len(path)):
        graph1.nodes[path[i - 1]]['color'] = 'red'
        graph1.edges[path[i - 1], path[i]]['color'] = 'red'
    graph1.nodes[path[-1]]['color'] = 'red'


#отображаем граф с решением
nt1 = Network(notebook=True)
nt1.set_options(options)
nt1.from_nx(graph1)
nt1.show("test1.html")
# Out:
#         <iframe
#             width="500px"
#             height="500px"
#             src="test1.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#тестовый блок для определения скорости работы алгоритма

tests = []

for i in range(6):
    temp_matrix = generate_matrix()
    node_counts = len(temp_matrix)
    edge_counts = 0
    for i in range(len(temp_matrix)):
        for j in range(i):
            if temp_matrix[j][i] != 0:
                edge_counts += 1
    t1 = time.time()
    c1 = random.randint(1, len(temp_matrix) // 2)
    c2 = random.randint(1, len(temp_matrix))
    result = levit(temp_matrix, c1, c2)
    t2 = time.time()
    delta = round((t2 - t1) * 1000)
    tests.append([node_counts, edge_counts, delta])

pd.DataFrame(tests, columns = ["Количество узлов", "Количество ребер", "Время в мс"])
# Out:
#    Количество узлов  Количество ребер  Время в мс
# 0                91              4095          41
# 1                88              3828          42
# 2                88              3828          29
# 3                41               820           7
# 4                54              1431          13
# 5                89              3916          35

# %%
#Алгоиртм Йена

#загрузка матрицы из файла
with open("mat2.txt", "r", encoding = "utf-8") as file:
    matrix = [[int(num) for num in line.split(" ")] for line in file]
    for i in range(len(matrix)):
        for j in range(len(matrix)):
            if matrix[i][j] == 0:
                matrix[i][j] = math.inf
#создаём граф
graph = create_graph(matrix)

# %%
#алгоритм
def yen(__matrix, v, u, K):
    v -= 1
    u -= 1
    matrix = copy.deepcopy(__matrix)
    N = len(matrix)
    temp = dijkstra(matrix, v + 1, u + 1)
    candidates = set()
    paths = [[el - 1 for el in temp[1]]]
    lengths = [temp[0][u]]
    if len(paths[0]) < 2:
        return ([], [])
    for k in range (1, K):
        cur_mat = copy.deepcopy(matrix)
        for i in range(len(paths[-1]) - 1):
            spur_node = paths[-1][i]
            root_path = paths[-1][:i + 1]
            
            for path in paths:
                if root_path == path[:i + 1]:
                    cur_mat[path[i]][path[i + 1]] = math.inf
            
            for node in root_path:
                if node != spur_node:
                    cur_mat[node] = [math.inf for j in range(N)]
            
            temp = dijkstra(cur_mat, spur_node + 1, u + 1)
            spur_path = [el - 1 for el in temp[1][1:]]
            if len(spur_path) < 1:
                continue
            
            total_path = root_path
            total_path.extend(spur_path)
            total_path = tuple(total_path)
            distance = 0
            for j in range(1, len(total_path)):
                distance += matrix[total_path[j - 1]][total_path[j]]

            candidates.add((total_path, distance))
        if len(candidates) == 0:
            break
        
        sorted_candidates = list(candidates)
        sorted_candidates.sort(key = lambda x : x[1])
        paths.append(list(sorted_candidates[0][0]))
        lengths.append(sorted_candidates[0][1])
        candidates.remove(sorted_candidates[0])
    for i in range(len(paths)):
        paths[i] = [el + 1 for el in paths[i]]
    return (paths, lengths)

result = yen(matrix, 1, 3, 3)
paths = result[0]
print(paths)

#вносим графические изменения
if len(path) > 0:
    for i in range(1, len(path)):
        graph1.nodes[path[i - 1]]['color'] = 'red'
        graph1.edges[path[i - 1], path[i]]['color'] = 'red'
    graph1.nodes[path[-1]]['color'] = 'red'


#отображаем граф с решением
nt1 = Network(notebook=True)
nt1.set_options(options)
nt1.from_nx(graph1)
nt1.show("test1.html")
# Out:
# [[1, 3], [1, 4, 3]]
#         <iframe
#             width="500px"
#             height="500px"
#             src="test1.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#тестовый блок для определения скорости работы алгоритма

tests = []

for i in range(6):
    temp_matrix = generate_matrix()
    node_counts = len(temp_matrix)
    edge_counts = 0
    for i in range(len(temp_matrix)):
        for j in range(i):
            if temp_matrix[j][i] != 0:
                edge_counts += 1
    t1 = time.time()
    c1 = random.randint(1, len(temp_matrix) // 2)
    c2 = random.randint(1, len(temp_matrix))
    c3 = random.randint(3, 10)
    result = yen(temp_matrix, c1, c2, c3)
    t2 = time.time()
    delta = round((t2 - t1) * 1000)
    tests.append([node_counts, edge_counts, c3, delta])

pd.DataFrame(tests, columns = ["Количество узлов", "Количество ребер", "Кол-во маршрутов", "Время в мс"])
# Out:
#    Количество узлов  Количество ребер  Кол-во маршрутов  Время в мс
# 0                68              2278                 5         196
# 1                35               595                 4          35
# 2                36               630                 4          49
# 3                46              1035                 8         172
# 4                75              2775                 6         261
# 5                83              3403                10         750

# %% [markdown]
# ### Вывод

# %% [markdown]
# Я научилась использовать алгоритмы и отображать графы интерактивно.
